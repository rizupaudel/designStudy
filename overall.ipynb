# %%
import os
import pandas as pd

# %%
# loading data from csvs - priming
priming_csvpath = 'priming/analysis/data/csvs/'
priming_password = pd.read_csv(os.path.join(priming_csvpath, 'password.csv'))
priming_quest = pd.read_csv(os.path.join(priming_csvpath, 'quest.csv'))
priming_csquestquant = pd.read_csv(os.path.join(priming_csvpath, 'csquestquant.csv'))
priming_demo = pd.read_csv(os.path.join(priming_csvpath, 'demo.csv'))

# loading data from csvs - guidance
guidance_csvpath = 'guidance/analysis/data/csvs/'
guidance_password = pd.read_csv(os.path.join(guidance_csvpath, 'password.csv'))
guidance_quest = pd.read_csv(os.path.join(guidance_csvpath, 'quest.csv'))
# guidance_csquestquant = pd.read_csv(os.path.join(guidance_csvpath, 'csquestquant.csv'))
# guidance_demo = pd.read_csv(os.path.join(guidance_csvpath, 'demo.csv'))

# %%
display(priming_password.head())
display(guidance_password.head())
# Out:
#    Password Strength  Motivation After Design  Hard to Remember  \
# 0                  2                        1                -3
# 1                  3                       -3                 3
# 2                  2                        2                -2
# 3                  2                        3                 2
# 4                  3                        3                 2
#
#    Guessed by Hacker  Guessed by FnF  Stronger than Usual  \
# 0                 -2              -3                   -1
# 1                 -3              -3                    0
# 2                 -1              -3                    2
# 3                 -3              -3                    2
# 4                 -3              -3                    3
#
#    Password Generation  Actual Strength        design
# 0                -1.25             -3.0      Metaphor
# 1                 1.75              3.0      Personal
# 2                -2.00             -1.5  Consequences
# ...
